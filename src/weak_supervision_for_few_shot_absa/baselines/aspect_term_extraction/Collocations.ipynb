# %% [markdown]
# # Collocations

# %%
#load all libraries
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
import spacy
import string
import datasets

# %% [markdown]
# Data: https://www.kaggle.com/datafiniti/hotel-reviews/data

# %%
#load reviews data
aw = datasets.load_dataset('amazon_us_reviews', 'Electronics_v1_00')['train']

# %%
print(aw[0])
print(aw.shape)
# Out:
# {'marketplace': 'US', 'customer_id': '41409413', 'review_id': 'R2MTG1GCZLR2DK', 'product_id': 'B00428R89M', 'product_parent': '112201306', 'product_title': 'yoomall 5M Antenna WIFI RP-SMA Female to Male Extensionl Cable', 'product_category': 'Electronics', 'star_rating': 5, 'helpful_votes': 0, 'total_votes': 0, 'vine': 0, 'verified_purchase': 1, 'review_headline': 'Five Stars', 'review_body': 'As described.', 'review_date': '2015-08-31'}
# (3093869, 15)

# %% [markdown]
# Extract only the reviews...

# %%
comments = aw.select(range(30000))['review_body']
print(comments[:10])
# Out:
# ['As described.', 'It works as advertising.', 'Works pissa', 'Did not work at all.', 'Works well. Bass is somewhat lacking but is present. Overall pleased with the item.', "The quality on these speakers is insanely good and doesn't sound muddy when adjusting bass. Very happy with these.", 'Wish I could give this product more than five stars. Lifesaver.', 'works great', 'Great sound and compact. Battery life seems good. Happy with this product.', 'It works well~~~']

# %% [markdown]
# ## Preprocessing

# %%
#function to remove non-ascii characters
def _removeNonAscii(s): return "".join(i for i in s if ord(i)<128)

# %%
print(aw[4]['review_body'])
print(comments[4])
# Out:
# Works well. Bass is somewhat lacking but is present. Overall pleased with the item.
# Works well. Bass is somewhat lacking but is present. Overall pleased with the item.

# %%
#remove non-ascii characters
comments = [_removeNonAscii(x) for x in comments]

# %%
#get stop words of all languages
STOPWORDS_DICT = {lang: set(nltk.corpus.stopwords.words(lang)) for lang in nltk.corpus.stopwords.fileids()}

# %%
#load spacy
nlp = spacy.load('en_core_web_sm')

# %%
#function to clean and lemmatize comments
def clean_comments(text):
    #remove punctuations
    regex = re.compile('[' + re.escape(string.punctuation) + '\\r\\t\\n]')
    nopunct = regex.sub(" ", str(text))
    #use spacy to lemmatize comments
    doc = nlp(nopunct, disable=['parser','ner'])
    lemma = [token.lemma_ for token in doc]
    return lemma

# %%
#apply function to clean and lemmatize comments
lemmatized = [clean_comments(x) for x in comments]

# %%
print(lemmatized[:5])
# Out:
# [['as', 'describe'], ['it', 'work', 'as', 'advertising'], ['work', 'pissa'], ['do', 'not', 'work', 'at', 'all'], ['work', 'well', ' ', 'Bass', 'be', 'somewhat', 'lacking', 'but', 'be', 'present', ' ', 'Overall', 'pleased', 'with', 'the', 'item']]

# %%
#make sure to lowercase everything
lemmatized = [[word.lower() for word in x] for x in lemmatized]

# %%
lemmatized[:5]
# Out:
# [['as', 'describe'],
#  ['it', 'work', 'as', 'advertising'],
#  ['work', 'pissa'],
#  ['do', 'not', 'work', 'at', 'all'],
#  ['work',
#   'well',
#   ' ',
#   'bass',
#   'be',
#   'somewhat',
#   'lacking',
#   'but',
#   'be',
#   'present',
#   ' ',
#   'overall',
#   'pleased',
#   'with',
#   'the',
#   'item']]

# %%
#turn all comments' tokens into one single list
unlist_comments = [item for items in lemmatized for item in items]

# %% [markdown]
# ## Initialize NLTK's Bigrams/Trigrams Finder

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

# %%
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(unlist_comments)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(unlist_comments)

# %% [markdown]
# ## 1. Counting Frequencies of Adjacent Words
# - Main idea: simply order by frequency
# - Issues: too sensitive to very frequent pairs and pronouns/articles/prepositions come up often
# - Solution: filter for only adjectives and nouns

# %%
bigram_freq = bigramFinder.ngram_fd.items()

# %%
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)

# %%
bigramFreqTable.head().reset_index(drop=True)
# Out:
#       bigram   freq
# 0     ( , i)  11580
# 1   (br,   )   8025
# 2    ( , br)   7101
# 3   ( , the)   6341
# 4  (br,    )   5838

# %%
bigramFreqTable[:10]
# Out:
#          bigram   freq
# 210      ( , i)  11580
# 192    (br,   )   8025
# 191     ( , br)   7101
# 1276   ( , the)   6341
# 290   (br,    )   5838
# 93     ( , and)   5481
# 291   (   , br)   5450
# 358     (  , i)   5315
# 269    ( , but)   5170
# 726     ( , it)   4726

# %%
#get english stopwords
en_stopwords = set(stopwords.words('english'))

# %%
#function to filter for ADJ/NN bigrams
def rightTypes(ngram):
    if '-pron-' in ngram or '' in ngram or ' 'in ngram or 't' in ngram:
        return False
    for word in ngram:
        if word in en_stopwords:
            return False
    acceptable_types = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_type = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in acceptable_types and tags[1][1] in second_type:
        return True
    else:
        return False

# %%
#filter bigrams
filtered_bi = bigramFreqTable[bigramFreqTable.bigram.map(lambda x: rightTypes(x))]

# %%
filtered_bi[:30]
# Out:
#                 bigram  freq
# 192           (br,   )  8025
# 290          (br,    )  5838
# 291          (   , br)  5450
# 1824  (sound, quality)  1487
# 64      (great, sound)   736
# 440   (great, product)   730
# 9956        (br,     )   612
# 434       (work, fine)   497
# 1915     (good, sound)   491
# 6036   (good, quality)   463
# 69     (battery, life)   453
# 120     (great, price)   430
# 1203       (great,   )   427
# 204           (  , br)   390
# 454    (good, product)   388
# 226       (stop, work)   377
# 1040        (work,   )   371
# 9386        (ear, bud)   356
# 5960   (high, quality)   296
# 1397     (product,   )   284
# 603      (hdmi, cable)   280
# 1076        (  , work)   272
# 607      (good, price)   271
# 846        (price,   )   268
# 2340     (speaker,   )   254
# 7443       (sound,   )   242
# 2887       (  , sound)   219
# 2274         (use,   )   218
# 6875        (good,   )   216
# 4509      (long, time)   211

# %%
trigram_freq = trigramFinder.ngram_fd.items()

# %%
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)

# %%
trigramFreqTable.head().reset_index(drop=True)
# Out:
#          trigram  freq
# 0  (br,    , br)  5322
# 1  (   , br,   )  4987
# 2   ( , br,    )  4797
# 3    ( , br,   )  1931
# 4     ( , 34,  )  1554

# %%
trigramFreqTable[:10]
# Out:
#                trigram  freq
# 310      (br,    , br)  5322
# 311      (   , br,   )  4987
# 425       ( , br,    )  4797
# 198        ( , br,   )  1931
# 280         ( , 34,  )  1554
# 510       ( , i, have)  1271
# 574        (br,   , i)  1251
# 338         ( , i, be)  1069
# 957  (for, the, price)  1045
# 818        ( , it, be)   987

# %%
def rightTypesTri(ngram):
    if '-pron-' in ngram or '' in ngram or ' 'in ngram or '  ' in ngram or 't' in ngram:
        return False
    for word in ngram:
        if word in en_stopwords:
            return False
    first_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    third_type = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(ngram)
    if tags[0][1] in first_type and tags[2][1] in third_type:
        return True
    else:
        return False

# %%
filtered_tri = trigramFreqTable[trigramFreqTable.trigram.map(lambda x: rightTypesTri(x))]

# %%
filtered_tri[:50]
# Out:
#                                trigram  freq
# 310                      (br,    , br)  5322
# 449                     (   , br,    )   277
# 15059                  (   , br,     )   154
# 3320            (good, sound, quality)   111
# 6961           (great, sound, quality)    83
# 14027         (great, little, speaker)    58
# 11437           (product, work, great)    51
# 23010                (micro, sd, card)    51
# 17263            (worth, every, penny)    46
# 18656              (work, great, work)    46
# 62                (work, great, great)    43
# 20672               (blu, ray, player)    36
# 77417       (noise, cancel, headphone)    35
# 10668      (excellent, sound, quality)    31
# 52208                  (    , br,    )    30
# 7100            (great, product, work)    28
# 78941          (bose, soundlink, mini)    27
# 53346             (great, work, great)    26
# 28812           (good, quality, cable)    25
# 22813   (portable, bluetooth, speaker)    25
# 42485             (cable, work, great)    24
# 1323             (sound, pretty, good)    23
# 35646              (work, great, good)    23
# 77672           (good, quality, sound)    23
# 80369             (usb, charge, cable)    22
# 8414            (great, battery, life)    22
# 100148         (home, theater, system)    22
# 13639       (great, customer, service)    21
# 47007           (high, quality, sound)    21
# 10031         (decent, sound, quality)    20
# 32966             (price, work, great)    20
# 38957                (big, box, store)    20
# 119914          (audio, technica, ath)    19
# 6857                (www, amazon, com)    19
# 65750                 (sd, card, slot)    19
# 39936              (work, well, great)    19
# 39369                (tv, wall, mount)    19
# 1358           (great, product, great)    18
# 46245           (poor, sound, quality)    18
# 162773         (great, great, product)    18
# 28441               (work, great,    )    17
# 81277            (order, another, one)    17
# 9514          (headphone, work, great)    17
# 878                (fine, work, great)    17
# 284961        (high, quality, product)    17
# 32225               (flat, screen, tv)    17
# 421009               (e, book, reader)    17
# 88187         (work, perfectly, great)    16
# 86260            (play, pause, button)    16
# 18462          (work, perfectly, fine)    16

# %%
freq_bi = filtered_bi[:20].bigram.values

# %%
freq_tri = filtered_tri[:20].trigram.values

# %% [markdown]
# ## 2. PMI

# %%
bigramFinder.apply_freq_filter(20)

# %%
bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)

# %%
bigramPMITable[:30]
# Out:
#                      bigram        PMI
# 0           (raspberry, pi)  15.263497
# 1                (hip, hop)  15.059964
# 2            (skull, candy)  14.912025
# 3          (timely, manner)  14.512726
# 4                  (wi, fi)  14.502685
# 5            (lithium, ion)  13.619641
# 6                 (v, moda)  13.389028
# 7                (blu, ray)  13.366993
# 8           (buyer, beware)  13.151668
# 9           (double, sided)  12.883375
# 10           (suction, cup)  12.796345
# 11                 (hi, fi)  12.714189
# 12              (xbox, 360)  12.619641
# 13         (family, member)  12.540704
# 14            (gold, plate)  12.314124
# 15  (pleasantly, surprised)  12.264213
# 16       (surge, protector)  12.190472
# 17         (user, friendly)  12.141101
# 18            (blue, tooth)  12.003397
# 19               (sd, card)  11.962471
# 20             (90, degree)  11.933281
# 21           (macbook, pro)  11.776742
# 22                 (16, gb)  11.555678
# 23           (kindle, fire)  11.554350
# 24                   (e, g)  11.520371
# 25            (sub, woofer)  11.509458
# 26              (micro, sd)  11.453442
# 27                 (32, gb)  11.394337
# 28            (heavy, duty)  11.371724
# 29       (water, resistant)  11.370127

# %%
trigramFinder.apply_freq_filter(20)

# %%
trigramPMITable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)

# %%
trigramPMITable[:30]
# Out:
#                         trigram        PMI
# 0             (micro, sd, card)  23.254938
# 1            (blu, ray, player)  22.505667
# 2         (worth, every, penny)  21.462817
# 3       (bose, soundlink, mini)  21.155696
# 4       (home, theater, system)  19.601036
# 5               (http,   , www)  19.257324
# 6                 (an, e, book)  19.050849
# 7                    (3, 5, mm)  18.987777
# 8     (exceed, my, expectation)  18.627924
# 9             (iphone, 6, plus)  18.480128
# 10                (5, mm, jack)  18.477275
# 11            (line, of, sight)  17.929229
# 12            (5, star, rating)  17.337185
# 13         (waste, your, money)  17.148914
# 14     (discount, in, exchange)  17.139858
# 15      (meet, my, expectation)  17.032803
# 16  (be, pleasantly, surprised)  17.019223
# 17             (male, to, male)  16.935502
# 18                 (16, gb, of)  16.811173
# 19            (big, box, store)  16.762718
# 20             (win, t, regret)  16.697119
# 21          (the, suction, cup)  16.691724
# 22      (honest, and, unbiased)  16.554246
# 23   (noise, cancel, headphone)  16.538795
# 24             (a, free, trial)  16.489514
# 25           (figure, out, how)  16.478280
# 26          (save, your, money)  16.433569
# 27            (no, matter, how)  16.105775
# 28           (a, deal, breaker)  16.077432
# 29           (less, than, half)  16.069154

# %%
pmi_bi = bigramPMITable[:20].bigram.values

# %%
pmi_tri = trigramPMITable[:20].trigram.values

# %% [markdown]
# ## 3. t-test

# %%
bigramTtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.student_t)), columns=['bigram','t']).sort_values(by='t', ascending=False)

# %%
bigramTtable.head()
# Out:
#       bigram          t
# 0   (br,   )  85.689633
# 1     ( , i)  78.877445
# 2  (br,    )  75.196321
# 3  (   , br)  72.571283
# 4    ( , br)  71.795710

# %%
filteredT_bi = bigramTtable[bigramTtable.bigram.map(lambda x: rightTypes(x))]

# %%
filteredT_bi[:10]
# Out:
#                bigram          t
# 0            (br,   )  85.689633
# 2           (br,    )  75.196321
# 3           (   , br)  72.571283
# 28   (sound, quality)  37.824835
# 90   (great, product)  25.818652
# 99     (great, sound)  24.953494
# 111        (br,     )  24.144028
# 145      (work, fine)  21.832810
# 156   (battery, life)  21.216578
# 169   (good, quality)  20.299661

# %%
trigramTtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.student_t)), columns=['trigram','t']).sort_values(by='t', ascending=False)

# %%
trigramTtable.head()
# Out:
#          trigram          t
# 0  (br,    , br)  72.938924
# 1  (   , br,   )  70.587515
# 2   ( , br,    )  69.164568
# 3    ( , br,   )  43.373776
# 4     ( , 34,  )  38.941694

# %%
filteredT_tri = trigramTtable[trigramTtable.trigram.map(lambda x: rightTypesTri(x))]

# %%
filteredT_tri.head(10)
# Out:
#                        trigram          t
# 0                (br,    , br)  72.938924
# 80              (   , br,    )  16.608229
# 221            (   , br,     )  12.402189
# 373     (good, sound, quality)  10.520428
# 609    (great, sound, quality)   9.089198
# 1080  (great, little, speaker)   7.608831
# 1294         (micro, sd, card)   7.141428
# 1322    (product, work, great)   7.104456
# 1522     (worth, every, penny)   6.782328
# 1600       (work, great, work)   6.688027

# %%
t_bi = filteredT_bi[:20].bigram.values

# %%
t_tri = filteredT_tri[:20].trigram.values

# %% [markdown]
# ## 4. Chi-Square

# %%
bigramChiTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','chi-sq']).sort_values(by='chi-sq', ascending=False)

# %%
bigramChiTable.head(20)
# Out:
#                  bigram        chi-sq
# 0            (hip, hop)  1.127229e+06
# 1       (raspberry, pi)  1.022683e+06
# 2            (blu, ray)  1.003637e+06
# 3        (skull, candy)  8.940443e+05
# 4    (surge, protector)  6.963535e+05
# 5      (timely, manner)  6.077523e+05
# 6              (wi, fi)  5.803262e+05
# 7            (sd, card)  4.708241e+05
# 8         (blue, tooth)  4.022801e+05
# 9   (customer, service)  3.786044e+05
# 10             (don, t)  3.674035e+05
# 11  (highly, recommend)  3.638687e+05
# 12            (br,    )  3.629382e+05
# 13       (suction, cup)  3.414033e+05
# 14            (   , br)  3.155742e+05
# 15      (buyer, beware)  3.002681e+05
# 16            (v, moda)  2.574407e+05
# 17        (heavy, duty)  2.569546e+05
# 18       (lithium, ion)  2.517159e+05
# 19            (didn, t)  2.125598e+05

# %%
trigramChiTable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.chi_sq)), columns=['trigram','chi-sq']).sort_values(by='chi-sq', ascending=False)

# %%
trigramChiTable.head(20)
# Out:
#                         trigram        chi-sq
# 0             (micro, sd, card)  5.106789e+08
# 1            (blu, ray, player)  2.147694e+08
# 2         (worth, every, penny)  1.329566e+08
# 3                    (3, 5, mm)  7.798257e+07
# 4       (bose, soundlink, mini)  6.310811e+07
# 5                 (br,    , br)  2.960363e+07
# 6               (http,   , www)  2.256044e+07
# 7     (exceed, my, expectation)  1.782767e+07
# 8       (home, theater, system)  1.760200e+07
# 9                 (an, e, book)  1.630560e+07
# 10                (   , br,   )  1.131717e+07
# 11         (waste, your, money)  1.110280e+07
# 12            (iphone, 6, plus)  9.888838e+06
# 13                (5, mm, jack)  8.841279e+06
# 14            (line, of, sight)  7.487941e+06
# 15     (discount, in, exchange)  6.940034e+06
# 16           (figure, out, how)  6.678190e+06
# 17      (honest, and, unbiased)  5.684406e+06
# 18          (easy, to, install)  4.669411e+06
# 19  (be, pleasantly, surprised)  4.655367e+06

# %%
chi_bi = bigramChiTable[:20].bigram.values

# %%
chi_tri = trigramChiTable[:20].trigram.values

# %% [markdown]
# ## 5. Likelihood

# %%
bigramLikTable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.likelihood_ratio)), columns=['bigram','likelihood ratio']).sort_values(by='likelihood ratio', ascending=False)

# %%
bigramLikTable.head()
# Out:
#       bigram  likelihood ratio
# 0  (br,    )      44562.478071
# 1   (br,   )      42101.448279
# 2  (   , br)      40229.892099
# 3   (don, t)      23078.896974
# 4    ( , br)      18647.169116

# %%
filteredLik_bi = bigramLikTable[bigramLikTable.bigram.map(lambda x: rightTypes(x))]

# %%
filteredLik_bi.head(10)
# Out:
#                   bigram  likelihood ratio
# 0              (br,    )      44562.478071
# 1               (br,   )      42101.448279
# 2              (   , br)      40229.892099
# 18      (sound, quality)       9635.285105
# 43       (battery, life)       4793.254238
# 74            (ear, bud)       3733.208953
# 76            (br,     )       3693.450715
# 90      (great, product)       3312.378407
# 100         (work, fine)       3123.905999
# 110  (customer, service)       2976.754797

# %%
trigramLikTable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.likelihood_ratio)), columns=['trigram','likelihood ratio']).sort_values(by='likelihood ratio', ascending=False)

# %%
trigramLikTable.head()
# Out:
#           trigram  likelihood ratio
# 0   (br,    , br)      92247.054718
# 1  (   , br,    )      90471.676319
# 2   (   , br,   )      87667.472912
# 3    ( , br,    )      67904.527773
# 4     ( , br,   )      65552.524632

# %%
filteredLik_tri = trigramLikTable[trigramLikTable.trigram.map(lambda x: rightTypesTri(x))]

# %%
filteredLik_tri.head(20)
# Out:
#                              trigram  likelihood ratio
# 0                      (br,    , br)      92247.054718
# 1                     (   , br,    )      90471.676319
# 10                   (    , br,    )      44629.507339
# 11                   (   , br,     )      43978.280525
# 696          (great, sound, quality)      12147.760874
# 738           (product, work, great)      11271.415116
# 750           (good, sound, quality)      11126.084836
# 761             (price, work, great)      11040.804026
# 763             (work, great, great)      10990.608007
# 764             (great, work, great)      10985.382516
# 765             (cable, work, great)      10984.621202
# 768              (work, great, good)      10979.673906
# 772              (work, great, work)      10967.301516
# 860      (excellent, sound, quality)      10017.418366
# 874         (decent, sound, quality)       9913.321504
# 1724          (great, battery, life)       4857.079262
# 2383          (great, product, work)       3573.536969
# 2709      (great, customer, service)       3053.784892
# 2735               (micro, sd, card)       3013.510719
# 2987  (portable, bluetooth, speaker)       2594.387168

# %%
lik_bi = filteredLik_bi[:20].bigram.values

# %%
lik_tri = filteredLik_tri[:20].trigram.values

# %% [markdown]
# ## Bigram Comparison

# %%
bigramsCompare = pd.DataFrame([freq_bi, pmi_bi, t_bi, chi_bi, lik_bi]).T

# %%
bigramsCompare.columns = ['Frequency With Filter', 'PMI', 'T-test With Filter', 'Chi-Sq Test', 'Likeihood Ratio Test With Filter']

# %%
bigramsCompare
# Out:
#    Frequency With Filter                      PMI   T-test With Filter  \
# 0               (br,   )          (raspberry, pi)             (br,   )
# 1              (br,    )               (hip, hop)            (br,    )
# 2              (   , br)           (skull, candy)            (   , br)
# 3       (sound, quality)         (timely, manner)     (sound, quality)
# 4         (great, sound)                 (wi, fi)     (great, product)
# 5       (great, product)           (lithium, ion)       (great, sound)
# 6             (br,     )                (v, moda)           (br,     )
# 7           (work, fine)               (blu, ray)         (work, fine)
# 8          (good, sound)          (buyer, beware)      (battery, life)
# 9        (good, quality)          (double, sided)      (good, quality)
# 10       (battery, life)           (suction, cup)        (good, sound)
# 11        (great, price)                 (hi, fi)       (great, price)
# 12           (great,   )              (xbox, 360)         (stop, work)
# 13              (  , br)         (family, member)           (ear, bud)
# 14       (good, product)            (gold, plate)      (good, product)
# 15          (stop, work)  (pleasantly, surprised)      (high, quality)
# 16            (work,   )       (surge, protector)        (hdmi, cable)
# 17            (ear, bud)         (user, friendly)        (good, price)
# 18       (high, quality)            (blue, tooth)  (customer, service)
# 19         (product,   )               (sd, card)         (long, time)
#
#             Chi-Sq Test Likeihood Ratio Test With Filter
# 0            (hip, hop)                        (br,    )
# 1       (raspberry, pi)                         (br,   )
# 2            (blu, ray)                        (   , br)
# 3        (skull, candy)                 (sound, quality)
# 4    (surge, protector)                  (battery, life)
# 5      (timely, manner)                       (ear, bud)
# 6              (wi, fi)                       (br,     )
# 7            (sd, card)                 (great, product)
# 8         (blue, tooth)                     (work, fine)
# 9   (customer, service)              (customer, service)
# 10             (don, t)                     (stop, work)
# 11  (highly, recommend)               (surge, protector)
# 12            (br,    )                   (great, sound)
# 13       (suction, cup)                    (hdmi, cable)
# 14            (   , br)                    (mp3, player)
# 15      (buyer, beware)                  (high, quality)
# 16            (v, moda)                       (sd, card)
# 17        (heavy, duty)                  (good, quality)
# 18       (lithium, ion)                       (blu, ray)
# 19            (didn, t)                   (great, price)

# %% [markdown]
# ## Trigram Comparison

# %%
trigramsCompare = pd.DataFrame([freq_tri, pmi_tri, t_tri, chi_tri, lik_tri]).T

# %%
trigramsCompare.columns = ['Frequency With Filter', 'PMI', 'T-test With Filter', 'Chi-Sq Test', 'Likeihood Ratio Test With Filter']

# %%
trigramsCompare
# Out:
#              Frequency With Filter                          PMI  \
# 0                    (br,    , br)            (micro, sd, card)
# 1                   (   , br,    )           (blu, ray, player)
# 2                  (   , br,     )        (worth, every, penny)
# 3           (good, sound, quality)      (bose, soundlink, mini)
# 4          (great, sound, quality)      (home, theater, system)
# 5         (great, little, speaker)              (http,   , www)
# 6           (product, work, great)                (an, e, book)
# 7                (micro, sd, card)                   (3, 5, mm)
# 8            (worth, every, penny)    (exceed, my, expectation)
# 9              (work, great, work)            (iphone, 6, plus)
# 10            (work, great, great)                (5, mm, jack)
# 11              (blu, ray, player)            (line, of, sight)
# 12      (noise, cancel, headphone)            (5, star, rating)
# 13     (excellent, sound, quality)         (waste, your, money)
# 14                 (    , br,    )     (discount, in, exchange)
# 15          (great, product, work)      (meet, my, expectation)
# 16         (bose, soundlink, mini)  (be, pleasantly, surprised)
# 17            (great, work, great)             (male, to, male)
# 18          (good, quality, cable)                 (16, gb, of)
# 19  (portable, bluetooth, speaker)            (big, box, store)
#
#                 T-test With Filter                  Chi-Sq Test  \
# 0                    (br,    , br)            (micro, sd, card)
# 1                   (   , br,    )           (blu, ray, player)
# 2                  (   , br,     )        (worth, every, penny)
# 3           (good, sound, quality)                   (3, 5, mm)
# 4          (great, sound, quality)      (bose, soundlink, mini)
# 5         (great, little, speaker)                (br,    , br)
# 6                (micro, sd, card)              (http,   , www)
# 7           (product, work, great)    (exceed, my, expectation)
# 8            (worth, every, penny)      (home, theater, system)
# 9              (work, great, work)                (an, e, book)
# 10            (work, great, great)                (   , br,   )
# 11              (blu, ray, player)         (waste, your, money)
# 12      (noise, cancel, headphone)            (iphone, 6, plus)
# 13     (excellent, sound, quality)                (5, mm, jack)
# 14                 (    , br,    )            (line, of, sight)
# 15          (great, product, work)     (discount, in, exchange)
# 16         (bose, soundlink, mini)           (figure, out, how)
# 17  (portable, bluetooth, speaker)      (honest, and, unbiased)
# 18            (great, work, great)          (easy, to, install)
# 19          (good, quality, cable)  (be, pleasantly, surprised)
#
#    Likeihood Ratio Test With Filter
# 0                     (br,    , br)
# 1                    (   , br,    )
# 2                   (    , br,    )
# 3                   (   , br,     )
# 4           (great, sound, quality)
# 5            (product, work, great)
# 6            (good, sound, quality)
# 7              (price, work, great)
# 8              (work, great, great)
# 9              (great, work, great)
# 10             (cable, work, great)
# 11              (work, great, good)
# 12              (work, great, work)
# 13      (excellent, sound, quality)
# 14         (decent, sound, quality)
# 15           (great, battery, life)
# 16           (great, product, work)
# 17       (great, customer, service)
# 18                (micro, sd, card)
# 19   (portable, bluetooth, speaker)
